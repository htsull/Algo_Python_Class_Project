# %% [markdown]
# * ## **Import tools and primary data**

# %%
import pandas as pd
df1 = pd.read_csv("usagers.csv")
df2 = pd.read_csv("vehicules.csv")
df3 = pd.read_csv("caract.csv")
df4 = pd.read_csv("lieux.csv")

# %% [markdown]
# * ## **Merge original data**

# %%
data = df1.merge(df2, on = ['id_vehicule', 'Num_Acc', 'num_veh'])
data = data.merge(df3, on = 'Num_Acc')
data = data.merge(df4, on = 'Num_Acc')
data.columns
# Out:
# Index(['Num_Acc', 'id_vehicule', 'num_veh', 'place', 'catu', 'grav', 'sexe',
#        'an_nais', 'trajet', 'secu1', 'secu2', 'secu3', 'locp', 'actp', 'etatp',
#        'senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'occutc',
#        'jour', 'mois', 'an', 'hrmn', 'lum', 'dep', 'com', 'agg', 'int', 'atm',
#        'col', 'adr', 'lat', 'long', 'catr', 'voie', 'v1', 'v2', 'circ', 'nbv',
#        'vosp', 'prof', 'pr', 'pr1', 'plan', 'lartpc', 'larrout', 'surf',
#        'infra', 'situ', 'vma'],
#       dtype='object')

# %% [markdown]
# * ## **Missing values handling**

# %% [markdown]
# + ### Dropping variables

# %%
# count nan values
nan_values = data.isna().sum()
# percentage of nan values ay column
nan_values = nan_values.sort_values(ascending=False) *100 / data.shape[0]
# columns with nan values greater than 20%
nan_values = nan_values.loc[nan_values > 20]
nan_values
# Out:
# long       100.000000
# lartpc      99.648811
# larrout     99.375080
# occutc      98.587726
# v2          92.673921
# dtype: float64

# %%
# Copy of original data
df = data.copy()
# Drop nan_values criteria columns
df = df.drop(nan_values.to_dict().keys(), axis=1)
# Drop other column not concerned by the process
df = df.drop('lat', axis=1)
df.columns, df.shape
# Out:
# (Index(['Num_Acc', 'id_vehicule', 'num_veh', 'place', 'catu', 'grav', 'sexe',
#         'an_nais', 'trajet', 'secu1', 'secu2', 'secu3', 'locp', 'actp', 'etatp',
#         'senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'jour', 'mois',
#         'an', 'hrmn', 'lum', 'dep', 'com', 'agg', 'int', 'atm', 'col', 'adr',
#         'catr', 'voie', 'v1', 'circ', 'nbv', 'vosp', 'prof', 'pr', 'pr1',
#         'plan', 'surf', 'infra', 'situ', 'vma'],
#        dtype='object'),
#  (132977, 48))

# %% [markdown]
# * ### Dropping rows

# %%
# Drop rows with any cells with nan values
df = df.dropna(axis=0, how='any')
df.shape
# Out:
# (104994, 48)

# %% [markdown]
# ===============================================================================

# %%
import datetime
# Create age variable from birth year 'an_nais'
df['age'] = datetime.date.today().year - df.an_nais
print('Dimension de df', df.shape)
# Out:
# Dimension de df (104994, 49)

# %%
# convert sexe as categorical
df.sexe = df.sexe.astype('category')
df.sexe.dtypes
# Out:
# CategoricalDtype(categories=[1, 2], ordered=False)

# %%
df.columns
# Out:
# Index(['Num_Acc', 'id_vehicule', 'num_veh', 'place', 'catu', 'grav', 'sexe',
#        'an_nais', 'trajet', 'secu1', 'secu2', 'secu3', 'locp', 'actp', 'etatp',
#        'senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 
NaN       NaN       NaN       NaN       NaN       NaN       NaN
# lum     -0.051357 -0.002901  0.075642  0.029463  0.007685 -0.051406 -0.124132
# agg     -0.440565 -0.165075 -0.063760  0.063848 -0.051982 -0.684503  0.009467
# int     -0.105573  0.036450 -0.012312  0.198254  0.000423 -0.174570  0.016749
# atm      0.007844  0.027733  0.241026  0.028500  0.025477  0.006562  0.013727
# col     -0.029998  0.030031  0.062362  0.035079  0.145904 -0.054859  0.019856
# catr    -0.381959 -0.056788 -0.027063  0.073265  0.008977 -0.566217  0.010928
# v1       0.023396  0.017885  0.000379  0.004370  0.017500 -0.000256  0.001327
# circ     0.117864 -0.010557  0.021725 -0.035602 -0.011557  0.216126 -0.017800
# nbv      0.174868 -0.061319  0.017359 -0.045384 -0.030752  0.359631 -0.027750
# vosp    -0.087520 -0.047621 -0.005732  0.059159  0.158523 -0.097270 -0.003377
# prof     0.048831  0.208416  0.058461  0.010156  0.022537  0.028795 -0.008557
# pr       0.088741  0.013530  0.016170 -0.012730  0.011760  0.159534  0.006153
# pr1      1.000000  0.081954  0.021414 -0.034806  0.036123  0.387960  0.008713
# plan     0.081954  1.000000  0.087132  0.029712  0.065085  0.042943 -0.014542
# surf     0.021414  0.087132  1.000000  0.028325  0.020977  0.039996 -0.019510
# infra   -0.034806  0.029712  0.028325  1.000000  0.021190 -0.105335  0.007075
# situ     0.036123  0.065085  0.020977  0.021190  1.000000  0.012142 -0.012289
# vma      0.387960  0.042943  0.039996 -0.105335  0.012142  1.000000 -0.017262
# age      0.008713 -0.014542 -0.019510  0.007075 -0.012289 -0.017262  1.000000
#
# [40 rows x 40 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20, 16))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# variance 
df.var().sort_values().head()
# Out:
# an      5.169928e-26
# v1      2.015286e-02
# agg     2.138907e-01
# prof    2.859882e-01
# plan    3.757334e-01
# dtype: float64

# %%
# dropping `an` variable
# df = df.drop('an', axis=1)

# %% [markdown]
# # Sklearn : Feature Selection

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Variance Threshold :
# - Elimine les variables dont la variance est inférieure à un certain seuil
# - Pour effectuer des prédictions, un estimateur a besoin d'informations qui varient en accord avec la Target

# %%
df1 = df.copy() # On fait la copie du DataFrame
df1 = data.loc[ : , data.columns != 'grav'] # On selectionne ttes les var sauf "grav"
df1.columns
# Out:
# Index(['Num_Acc', 'id_vehicule', 'num_veh', 'place', 'catu', 'sexe', 'an_nais',
#        'trajet', 'secu1', 'secu2', 'secu3', 'locp', 'actp', 'etatp', 'senc',
#        'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'occutc', 'jour',
#        'mois', 'an', 'hrmn', 'lum', 'dep', 'com', 'agg', 'int', 'atm', 'col',
#        'adr', 'lat', 'long', 'catr', 'voie', 'v1', 'v2', 'circ', 'nbv', 'vosp',
#        'prof', 'pr', 'pr1', 'plan', 'lartpc', 'larrout', 'surf', 'infra',
#        'situ', 'vma'],
#       dtype='object')

# %%
# Out:
#              Num_Acc  id_vehicule num_veh  place  catu  sexe  an_nais  trajet  \
# 0       201900000001  138 306 524     B01      2     2     2     2002       0
# 1       201900000001  138 306 524     B01      1     1     2     1993       5
# 2       201900000001  138 306 525     A01      1     1     1     1959       0
# 3       201900000002  138 306 523     A01      1     1     2     1994       0
# 4       201900000003  138 306 520     A01      1     1     1     1996       0
# ...              ...          ...     ...    ...   ...   ...      ...     ...
# 132972  201900058837  137 982 135     C01      1     1     2     1988       1
# 132973  201900058838  137 982 132     A01      1     1     1     1998       9
# 132974  201900058839  137 982 131     A01      1     1     1     1979       0
# 132975  201900058840  137 982 129     B01      1     1     1     1974       0
# 132976  201900058840  137 982 130     A01      1     1     1     1971       0
#
#         secu1  secu2  ...  prof     pr    pr1  plan  lartpc  larrout  surf  \
# 0           1      0  ...   1.0    6.0  900.0   2.0     NaN      NaN   1.0
# 1           1      0  ...   1.0    6.0  900.0   2.0     NaN      NaN   1.0
# 2           1      0  ...   1.0    6.0  900.0   2.0     NaN      NaN   1.0
# 3           1      0  ...   4.0    3.0  845.0   2.0     NaN      NaN   1.0
# 4           1      0  ...   1.0   10.0  500.0   3.0     NaN      NaN   1.0
# ...       ...    ...  ...   ...    ...    ...   ...     ...      ...   ...
# 132972      1      0  ...   1.0  303.0  282.0   1.0     NaN      NaN   2.0
# 132973      1      0  ...   1.0    5.0  199.0   1.0     NaN      NaN   1.0
# 132974      2      0  ...   1.0   59.0   99.0   3.0     NaN      NaN   1.0
# 132975      1      0  ...   1.0    6.0  699.0   1.0     NaN      NaN   1.0
# 132976      1     -1  ...   1.0    6.0  699.0   1.0     NaN      NaN   1.0
#
#         infra  situ    vma
# 0         2.0   1.0   70.0
# 1         2.0   1.0   70.0
# 2         2.0   1.0   70.0
# 3         0.0   1.0   70.0
# 4         0.0   1.0   90.0
# ...       ...   ...    ...
# 132972    0.0   1.0   90.0
# 132973    0.0   1.0   90.0
# 132974    0.0   1.0   50.0
# 132975    0.0   2.0  110.0
# 132976    0.0   2.0  110.0
#
# [132977 rows x 53 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-2c832a4718ad> in <module>
# ----> 1 df1.grav
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'grav'

# %%
# features selection for model
y = df['grav']

features = ['catu','sexe','trajet',
            'catv','an_nais','mois',
            'obs','obsm','choc','manv',
            'lum','agg','int','atm','col',
            'catr','circ','vosp','prof','plan',
            'surf','infra','situ']

# %%
df.grav.unique()
# Out:
# array([4, 1, 3, 2], dtype=int64)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score

# %%
# hot encoding of the features
X_data = pd.get_dummies(df[features].astype(str))

# %%
# On commence par normaliser les données :

X_N_data = normalize(X_data.values)

# %%
# On divise la base en bases d'entraînements et de test :

X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X_N_data, y)
# On construit le modèle :

model_rf = RandomForestClassifier(n_estimators=100)
# L'entrînement commence :

model_rf.fit(X_train_rf, y_train_rf)
# On a maintenant les prédictions pour la base de test

predictions_test = model_rf.predict(X_test_rf)
# On calcul de même les prédictions pour la base train

predictions_train = model_rf.predict(X_train_rf)
# Les résultats sont calculés de cette manière :

train_acc = accuracy_score(y_train_rf, predictions_train)
print(train_acc)

test_acc = accuracy_score(y_test_rf, predictions_test)
print(test_acc)
# Out:
# 0.9987300781001969
# 0.6913406224999048

# %%
# On redécoupe la base en train/test

X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(X_N_data, y)


# On crée le modèle :

model_boosting = GradientBoostingClassifier(loss="deviance",
    learning_rate=0.2,
    max_depth=5,
    max_features="sqrt",
    subsample=0.95,
    n_estimators=200)


model_boosting.fit(X_train_xgb, y_train_xgb)

# On calcul les prédictions
predictions_test_xgb = model_boosting.predict(X_test_xgb)
predictions_train_xgb = model_boosting.predict(X_train_xgb)

# On affiche les résultats :

train_acc = accuracy_score(y_train_xgb, predictions_train_xgb)
print(train_acc)

test_acc = accuracy_score(y_test_xgb, predictions_test_xgb)
print(test_acc)
# Out:
# 0.7266112134103753
# 0.6895881747876109

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test_xgb, predictions_test_xgb))
print(classification_report(y_test_xgb, predictions_test_xgb))
# Out:
# [[9258   15  163 1812]
#  [  48   29  176  199]
#  [ 361   70  755 2076]
#  [2723   46  459 8059]]
#               precision    recall  f1-score   support
#
#            1       0.75      0.82      0.78     11248
#            2       0.18      0.06      0.09       452
#            3       0.49      0.23      0.31      3262
#            4       0.66      0.71      0.69     11287
#
#     accuracy                           0.69     26249
#    macro avg       0.52      0.46      0.47     26249
# weighted avg       0.67      0.69      0.67     26249

# %%
from sklearn.metrics import plot_confusion_matrix

disp = plot_confusion_matrix(model_boosting, X_test_xgb, y_test_xgb, 
                             cmap='Reds', values_format='d', 
                             display_labels=["Indemne", "Tué", "Blessé hospitalisé", "Blessé léger"])

# %% [markdown]
# # - verification de la disproportion entre les modalites des variables

# %%
df['sexe'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 1    68.020077
# 2    31.979923
# Name: sexe, dtype: float64

# %%
df['grav'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 1    42.647199
# 2     1.857249
# 3    12.144503
# 4    43.351049
# Name: grav, dtype: float64

# %%
df['lum'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 1    66.321885
# 2     5.947959
# 3     8.671924
# 4     0.967674
# 5    18.090558
# Name: lum, dtype: float64

# %%
df['agg'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 1    30.997009
# 2    69.002991
# Name: agg, dtype: float64

# %%
df['int'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 1    63.621731
# 2    13.322666
# 3    10.762520
# 4     2.270606
# 5     0.599082
# 6     3.387813
# 7     1.288645
# 8     0.079052
# 9     4.667886
# Name: int, dtype: float64

# %%
df['atm'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 1    79.529306
# 2    11.444463
# 3     2.286797
# 4     0.364783
# 5     0.440978
# 6     0.239061
# 7     1.470560
# 8     3.784026
# 9     0.440025
# Name: atm, dtype: float64

# %%
df['col'].value_counts(sort=True) *100 / df.shape[0]
# Out:
# 3    31.860868
# 6    26.156733
# 2    14.487495
# 1     8.251900
# 4     7.870926
# 5     5.796522
# 7     5.575557
# Name: col, dtype: float64

# %%
df['catr'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 1    12.580719
# 2     6.937539
# 3    29.851230
# 4    46.650285
# 5     0.107625
# 6     0.600987
# 7     2.526811
# 9     0.744804
# Name: catr, dtype: float64

# %%
# -1 problem

df['circ'].value_counts(sort=False) *100 / df.shape[0]
# Out:
#  4.0     0.706707
#  3.0    17.488618
#  1.0    20.433549
# -1.0     5.439358
#  2.0    55.931768
# Name: circ, dtype: float64

# %%
df['surf'].value_counts(sort=False) *100 / df.shape[0]
# Out:
#  4.0     0.027621
#  8.0     0.140960
#  3.0     0.178105
#  1.0    80.311256
# -1.0     0.002857
#  7.0     0.238109
#  2.0    18.652494
#  5.0     0.121912
#  9.0     0.312399
#  6.0     0.014287
# Name: surf, dtype: float64

# %%
df['infra'].value_counts(sort=False) *100 / df.shape[0]
# Out:
#  0.0    82.479951
#  4.0     0.445740
#  8.0     0.921957
#  3.0     1.592472
#  1.0     1.644856
# -1.0     0.070480
#  7.0     0.052384
#  2.0     2.152504
#  5.0     5.860335
#  9.0     3.884031
#  6.0     0.895289
# Name: infra, dtype: float64

# %%
df['catv'].value_counts(sort=False) *100 / df.shape[0]
# Out:
# 0      0.190487
# 1      4.005943
# 2      2.729680
# 3      0.985771
# 7     63.239804
# 10     7.055641
# 13     0.348591
# 14     0.656228
# 15     0.690516
# 16     0.030478
# 80     0.197154
# 17     0.561937
# 20     0.202869
# 21     0.120007
# 30     3.277330
# 31     1.663905
# 32     2.478237
# 33     6.724194
# 34     1.374364
# 35     0.009524
# 99     0.399070
# 36     0.069528
# 37     1.169591
# 38     0.279064
# 39     0.027621
# 40     0.177153
# 41     0.010477
# 42     0.036193
# 43     0.509553
# 50     0.658133
# 60     0.120959
# Name: catv, dtype: float64

# %% [markdown]
# # Questions
# ## 1. Comment les modalites avec les petites representations vont affecter le modele?
# ## 2. Quels sont les algos de classifications qu'on peut encore essayer pour ameliorer?
# ## 3. Prisen en comptes des suggestions se l'article, comment s'y prendre? (https://larevueia.fr/xgboost-vs-random-forest-predire-la-gravite-dun-accident-de-la-route/)
# ## 4. Suggestions?

# %% [markdown]
# ### Créer notre SVM dans sklearn en créant un objet SVC (support vector classificator).

# %%
##### Création de notre modèle SVM

# %%
X_train_SVM, X_test_SVM, y_train_SVM, y_test_SVM = \
    train_test_split(X_N_data, y,
                     test_size=0.2)

# %%
print(len(X_train_SVM),' samples in training data\n',
      len(X_test_SVM),' samples in test data\n', )
# Out:
# 83995  samples in training data
#  20999  samples in test data

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', gamma="" random_state = 0) # kernel linéaire
classifier.fit(X_train_SVM, y_train_SVM)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# # Faire la prédiction

# %%
y_pred1 = classifier.predict(X_test_SVM)

# %%
# Evaluer le modèle

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test_SVM, y_pred1))
print(classification_report(y_test_SVM, y_pred1))
# Out:
# [[7276    0    7 1646]
#  [  64    0    8  321]
#  [ 423    0   40 2108]
#  [2620    0   25 6461]]
#               precision    recall  f1-score   support
#
#            1       0.70      0.81      0.75      8929
#            2       0.00      0.00      0.00       393
#            3       0.50      0.02      0.03      2571
#            4       0.61      0.71      0.66      9106
#
#     accuracy                           0.66     20999
#    macro avg       0.45      0.38      0.36     20999
# weighted avg       0.63      0.66      0.61     20999
# C:\Users\cleme\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\cleme\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\cleme\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import plot_confusion_matrix

disp = plot_confusion_matrix(classifier, X_test_SVM, y_test_SVM, 
                             cmap='Reds', values_format='d', 
                             display_labels=["Indemne", "Tué", "Blessé hospitalisé", "Blessé léger"])
